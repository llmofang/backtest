# %%
import pandas as pd
from datetime import datetime
from dateutil import parser

# %%
df=pd.read_csv('stock_2016-02-26_tick2_processed.csv')

# %%
ndate=df['time'].iloc[0][1:-1]

# %%
ndate=ndate[2:-10]

# %%
ndate=str(df['nActionDay'].iloc[0])+" "+ndate

# %%
 parser.parse(ndate)
# Out:
# datetime.datetime(2016, 2, 26, 9, 44, 5)

# %%
df
# Out:
#        iTurnover   iVolume  nActionDay  nAskPrice1  nAskPrice10  nAskPrice2  \
# 0      274044493   8314496    20160226      331300       332700      331400
# 1      274431947   8326196    20160226      331300       332700      331400
# 2      275110547   8346696    20160226      331000       332100      331100
# 3      275401729   8355496    20160226      331000       332100      331100
# 4      275603535   8361596    20160226      331000       332100      331100
# 5      275663075   8363396    20160226      331000       332100      331100
# 6      276149104   8378096    20160226      330400       331900      330500
# 7      277459508   8417696    20160226      330200       331900      330600
# 8      279849323   8489997    20160226      331100       332200      331200
# 9      280428588   8507497    20160226      331100       332200      331200
# 10     280716115   8516197    20160226      330200       331500      330500
# ...
